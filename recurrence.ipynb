# %% [markdown]
# # Recurrence

# %% [markdown]
# Approaches
#
# 1. Unrolling
# 2. Tree Method
# 3. Master Theorem
#
# To Remember:
# - binary search recurrance
# - merge sort recurrance
#
# ![image.png](attachment:image.png)
